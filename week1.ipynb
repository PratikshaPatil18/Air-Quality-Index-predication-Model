# %% [markdown]
# <a href="https://colab.research.google.com/github/PratikshaPatil18/Air-Quality-Index-predication-Model/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset.csv')
df.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year    Make  \
# 0  2T3YL4DV0E      King  Bellevue    WA        98005        2014  TOYOTA
# 1  5YJ3E1EB6K      King   Bothell    WA        98011        2019   TESLA
# 2  5UX43EU02S  Thurston   Olympia    WA        98502        2025     BMW
# 3  JTMAB3FV5R  Thurston   Olympia    WA        98513        2024  TOYOTA
# 4  5YJYGDEE8M    Yakima     Selah    WA        98942        2021   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0        RAV4          Battery Electric Vehicle (BEV)
# 1     MODEL 3          Battery Electric Vehicle (BEV)
# 2          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     MODEL Y          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           103.0
# ...

# %%
#shape - rows and column
df.shape
# Out:
# (208184, 17)

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208184 entries, 0 to 208183
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         208184 non-null  object
#  1   County                                             208184 non-null  object
#  2   City                                               208184 non-null  object
#  3   State                                              208184 non-null  object
#  4   Postal Code                                        208184 non-null  int64
#  5   Model Year                                         208184 non-null  int64
#  6   Make                                               208184 non-null  object
#  7   Model                                              208184 non-null  object
# ...

# %%
#to know duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#to check missing values
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        27
# Base MSRP                                             27
# Legislative District                                 154
# DOL Vehicle ID                                         0
# Vehicle Location                                       6
# Electric Utility                                       0
# ...

# %%
#drop the row where 'AQI' has missing values
df.dropna(subset=['AQI'],inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Legislative District                                 154
# Base MSRP                                             27
# Electric Range                                        27
# Vehicle Location                                       6
# VIN (1-10)                                             0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Utility                                       0
# DOL Vehicle ID                                         0
# Electric Vehicle Type                                  0
# County                                                 0
# Model                                                  0
# Make                                                   0
# Model Year                                             0
# Postal Code                                            0
# State                                                  0
# City                                                   0
# ...

# %%
#summary of statistics int dataset
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  208184.000000  208184.000000   208157.000000  208157.000000
# mean    98224.009093    2021.326682       47.278607     808.814164
# std      1525.414775       3.006033       84.638601    7283.104443
# min      1731.000000    1999.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98121.000000    2022.000000        0.000000       0.000000
# 75%     98368.000000    2023.000000       39.000000       0.000000
# max     99403.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         208030.000000    2.081840e+05       2.081840e+05
# mean              29.191203    2.339884e+08       5.301782e+10
# std               14.931326    6.894214e+07       9.231083e+08
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
#transpose rows as column and column as row
df.describe().T
# Out:
#                          count          mean           std           min  \
# Postal Code           208184.0  9.822401e+04  1.525415e+03  1.731000e+03
# Model Year            208184.0  2.021327e+03  3.006033e+00  1.999000e+03
# Electric Range        208157.0  4.727861e+01  8.463860e+01  0.000000e+00
# Base MSRP             208157.0  8.088142e+02  7.283104e+03  0.000000e+00
# Legislative District  208030.0  2.919120e+01  1.493133e+01  1.000000e+00
# DOL Vehicle ID        208184.0  2.339884e+08  6.894214e+07  4.385000e+03
# 2020 Census Tract     208184.0  5.301782e+10  9.231083e+08  1.001020e+09
#
#                                25%           50%           75%           max
# Postal Code           9.805200e+04  9.812100e+04  9.836800e+04  9.940300e+04
# Model Year            2.020000e+03  2.022000e+03  2.023000e+03  2.025000e+03
# Electric Range        0.000000e+00  0.000000e+00  3.900000e+01  3.370000e+02
# Base MSRP             0.000000e+00  0.000000e+00  0.000000e+00  8.450000e+05
# ...

# %%
#percentage of null values
null_values_percentage=(df.isnull().sum())
null_values_percentage
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        27
# Base MSRP                                             27
# Legislative District                                 154
# DOL Vehicle ID                                         0
# Vehicle Location                                       6
# Electric Utility                                       0
# ...

# %% [markdown]
# Key considerations:
#  * Xylene has highes percentage of missing values - 61.86%
#  * PM10 & NH3 = 28-26%
